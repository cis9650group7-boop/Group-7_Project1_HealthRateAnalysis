# %% [markdown]
# Set up and Environment

# %%
# Set up and Envirionment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data Loading

# %%
df = pd.read_csv("CIS9650_Project 01_healthrate.ratemd.ny.csv")
# Out:
# /var/folders/9g/hd6rk0px3dq9grqrwxn981w40000gn/T/ipykernel_53680/2984594286.py:1: DtypeWarning: Columns (31,32,34,36,65,74,75,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,404,405,406,407,410,411,412,413,414,415,416,417,418,419,420,421,422,423,424,425,426,427,428,429,432,433,434,435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,498,499,500,501,502,503,504,505,506,507,508,509,510,511,512,513,514,515,516,517,520,521,522,523,524,525,526,527,528,529,530,531,532,533,534,535,536,537,538,539,542,543,544,545,546,547,548,549,550,551,552,553,554,555,556,557,558,559,560,561,563,564,565,566,567,568,569,570,571,572,573,574,575,576,577,578,579,580,583,608,609,610,611,612,613,614,615,616,617,618,619,620,621,622,623,624,625,626,627,629,630,631,632,633,634,635,636,637,638,639,640,641,642,643,644,645,646,647,648,649,650,651,652,653,654,655,656,657,658,659,660,661,662,663,664,665,666,667,668,669,672,673,716,717,718,719,720,721,722,723,724,725,726,727,728,729,730,731,732,733,734,735,739,740,741,742,743,744,745,746,747,748,749,750,751,752,753,754,755,756,760,761,762,763,764,765,766,767,768,771,776,784,785,786,787,788,789,790,791,792,793,794,795,796,797,798,799,800,801,802,803,806,807,808,809,810,811,812,813,814,815,816,817,818,819,820,821,822,823,824,825,828,829,830,831,832,833,834,835,836,837,838,839,840,841,842,843,844,845,846,847,850,851,852,853,854,855,856,857,858,859,860,861,862,863,864,865,866,867,868,869,872,873,874,875,876,877,878,879,880,881,882,883,884,885,886,887,888,889,890,891,1048,1049,1050,1051,1052,1053,1054,1055,1056,1057,1058,1059,1060,1061,1062,1063,1064,1065,1066,1067,1070,1071,1072,1073,1074,1075,1076,1077,1078,1079,1080,1081,1082,1083,1084,1085,1086,1087,1088,1089,1112,1113,1114,1115,1116,1117,1118,1119,1120,1121,1122,1123,1124,1125,1126,1127,1128,1129,1130,1134,1135,1142,1152,1153,1154,1155,1156,1157,1158,1159,1160,1170,1171,1172,1173,1174,1175,1176,1177,1178,1179,1180,1181,1182,1183,1184,1185,1186,1187,1188,1189,1190,1191,1192,1193,1194,1195,1196,1197,1198,1199,1200,1201,1202,1203,1204,1205,1206,1207,1208,1209,1210,1211,1212,1213,1214,1215,1216,1217,1218,1219,1220,1221,1222,1223,1233,1234,1235,1236,1237,1238,1239,1240,1241,1242,1243,1244,1245,1246,1247,1248,1249,1250,1251,1252,1253,1254,1255,1256,1257,1258,1259,1278,1279,1280,1281,1282,1283,1284,1285,1286,1296,1297,1298,1299,1300,1301,1302,1303,1304,1305,1306,1307,1308,1309,1310,1311,1312,1313,1314,1315,1316,1317,1318,1319,1320,1321,1322,1323,1324,1325,1326,1327,1328,1329,1330,1331,1332,1333,1334,1335,1336,1337,1338,1339,1340,1341,1342,1343,1344,1345,1346,1347,1348,1349,1350,1351,1352,1353,1354,1355,1356,1357,1358,1359,1360,1361,1362,1363,1364,1365,1366,1367,1368,1369,1370,1371,1372,1373,1374,1375,1376,1377,1378,1379,1380,1381,1382,1383,1384,1385,1386,1387,1388,1389,1390,1391,1392,1393,1394,1395,1396,1397,1398,1399,1400,1401,1413,1414,1415,1416,1417,1418,1419,1420,1421,1422,1423,1424,1425,1426,1427,1428,1429,1430,1431,1432,1433,1434,1435,1436,1437,1438,1439,1440,1441,1442,1443,1444,1445,1446,1447,1448,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472, ...
#   df = pd.read_csv("CIS9650_Project 01_healthrate.ratemd.ny.csv")

# %%
df.shape
# row, column
# Out:
# (143791, 1611)

# %%
df.columns.tolist()
# Out:
# ['_id',
#  'slug',
#  'created',
#  'modified',
#  'id',
#  'facet_url',
#  'full_name',
#  'full_name_specialty',
#  'location.id',
#  'location.category',
#  'location.created',
#  'location.modified',
#  'location.longitude',
#  'location.latitude',
#  'location.slug',
#  'location.city.id',
#  'location.city.province_name',
#  'location.city.province_slug',
#  'location.city.country_name',
#  'location.city.country_slug',
#  'location.city.cover_images.253x83',
#  'location.city.cover_images.autoxauto',
#  'location.city.modified',
#  'location.city.created',
#  'location.city.deleted',
#  'location.city.slug',
#  'location.city.name',
#  'location.city.cover_image',
#  'location.city.province',
#  'location.name',
#  'location.address',
#  'location.suite',
#  'location.postal_code',
#  'location.city_id',
#  'location.phone_number',
#  'location.website',
#  'location.image',
#  'location.images.autoxauto',
#  'location.images.77x77',
#  'location.images.100x100',
#  'location.images.165x165',
#  'location.images.70x70',
#  'location.rating.cleanliness',
#  'location.rating.facilities',
#  'location.rating.services',
#  'location.rating.bestRating',
#  'location.rating.average',
#  'location.rating.value',
#  'location.rating.count',
#  'location.url',
#  'location.geocode_address',
#  'images.32x32',
#  'images.77x77',
#  'images.100x100',
#  'images.165x165',
#  'images.autoxauto',
#  'rating.average',
#  'rating.staff',
#  'rating.punctuality',
#  'rating.helpfulness',
#  'rating.bestRating',
#  'rating.knowledge',
#  'rating.count',
#  'sample_rating_comment',
#  'sample_rating_pk',
#  'vanity_specialty',
#  'specialty',
#  'specialty_name',
#  'url',
#  'verified',
#  'enhanced_ad_enabled',
#  'appointments_enabled',
#  'appointments_available',
#  'appointments_enabled_zocdoc',
#  'zocdoc_doctor_profile_url',
#  'accepting_virtual_appointments',
#  'accepting_virtual_appointments_zocdoc',
#  'ratings_disabled',
#  'doctor_locations[0].id',
#  'doctor_locations[1].id',
#  'doctor_locations[2].id',
#  'doctor_locations[3].id',
#  'doctor_locations[4].id',
#  'doctor_locations[5].id',
#  'doctor_locations[6].id',
#  'doctor_locations[7].id',
#  'doctor_locations[8].id',
#  'doctor_locations[9].id',
#  'doctor_locations[10].id',
#  'doctor_locations[11].id',
#  'doctor_locations[12].id',
#  'doctor_locations[13].id',
#  'doctor_locations[14].id',
#  'doctor_locations[15].id',
#  'doctor_locations[16].id',
#  'doctor_locations[17].id',
#  'doctor_locations[18].id',
#  'doctor_locations[19].id',
#  'doctor_locations[20].id',
#  'doctor_locations[21].id',
#  'doctor_locations[0].primary',
#  'doctor_locations[1].primary',
#  'doctor_locations[2].primary',
#  'doctor_locations[3].primary',
#  'doctor_locations[4].primary',
#  'doctor_locations[5].primary',
#  'doctor_locations[6].primary',
#  'doctor_locations[7].primary',
#  'doctor_locations[8].primary',
#  'doctor_locations[9].primary',
#  'doctor_locations[10].primary',
#  'doctor_locations[11].primary',
#  'doctor_locations[12].primary',
#  'doctor_locations[13].primary',
#  'doctor_locations[14].primary',
#  'doctor_locations[15].primary',
#  'doctor_locations[16].primary',
#  'doctor_locations[17].primary',
#  'doctor_locations[18].primary',
#  'doctor_locations[19].primary',
#  'doctor_locations[20].primary',
#  'doctor_locations[21].primary',
#  'doctor_locations[0].verified',
#  'doctor_locations[1].verified',
#  'doctor_locations[2].verified',
#  'doctor_locations[3].verified',
#  'doctor_locations[4].verified',
#  'doctor_locations[5].verified',
#  'doctor_locations[6].verified',
#  'doctor_locations[7].verified',
#  'doctor_locations[8].verified',
#  'doctor_locations[9].verified',
#  'doctor_locations[10].verified',
#  'doctor_locations[11].verified',
#  'doctor_locations[12].verified',
#  'doctor_locations[13].verified',
#  'doctor_locations[14].verified',
#  'doctor_locations[15].verified',
#  'doctor_locations[16].verified',
#  'doctor_locations[17].verified',
#  'doctor_locations[18].verified',
#  'doctor_locations[19].verified',
#  'doctor_locations[20].verified',
#  'doctor_locations[21].verified',
#  'doctor_locations[0].location.id',
#  'doctor_locations[1].location.id',
#  'doctor_locations[2].location.id',
#  'doctor_locations[3].location.id',
#  'doctor_locations[4].location.id',
#  'doctor_locations[5].location.id',
#  'doctor_locations[6].location.id',
#  'doctor_locations[7].location.id',
#  'doctor_locations[8].location.id',
#  'doctor_locations[9].location.id',
#  'doctor_locations[10].location.id',
#  'doctor_locations[11].location.id',
#  'doctor_locations[12].location.id',
#  'doctor_locations[13].location.id',
#  'doctor_locations[14].location.id',
#  'doctor_locations[15].location.id',
#  'doctor_locations[16].location.id',
#  'doctor_locations[17].location.id',
#  'doctor_locations[18].location.id',
#  'doctor_locations[19].location.id',
#  'doctor_locations[20].location.id',
#  'doctor_locations[21].location.id',
#  'doctor_locations[0].location.category',
#  'doctor_locations[1].location.category',
#  'doctor_locations[2].location.category',
#  'doctor_locations[3].location.category',
#  'doctor_locations[4].location.category',
#  'doctor_locations[5].location.category',
#  'doctor_locations[6].location.category',
#  'doctor_locations[7].location.category',
#  'doctor_locations[8].location.category',
#  'doctor_locations[9].location.category',
#  'doctor_locations[10].location.category',
#  'doctor_locations[11].location.category',
#  'doctor_locations[12].location.category',
#  'doctor_locations[13].location.category',
#  'doctor_locations[14].location.category',
#  'doctor_locations[15].location.category',
#  'doctor_locations[16].location.category',
#  'doctor_locations[17].location.category',
#  'doctor_locations[18].location.category',
#  'doctor_locations[19].location.category',
#  'doctor_locations[20].location.category',
#  'doctor_locations[21].location.category',
#  'doctor_locations[0].location.created',
#  'doctor_locations[1].location.created',
#  'doctor_locations[2].location.created',
#  'doctor_locations[3].location.created',
#  'doctor_locations[4].location.created',
#  'doctor_locations[5].location.created',
#  'doctor_locations[6].location.created',
#  'doctor_locations[7].location.created',
#  'doctor_locations[8].location.created',
#  'doctor_locations[9].location.created',
#  'doctor_locations[10].location.created',
#  'doctor_locations[11].location.created',
#  'doctor_locations[12].location.created',
#  'doctor_locations[13].location.created',
#  'doctor_locations[14].location.created',
#  'doctor_locations[15].location.created',
#  'doctor_locations[16].location.created',
#  'doctor_locations[17].location.created',
#  'doctor_locations[18].location.created',
#  'doctor_locations[19].location.created',
#  'doctor_locations[20].location.created',
#  'doctor_locations[21].location.created',
#  'doctor_locations[0].location.modified',
#  'doctor_locations[1].location.modified',
#  'doctor_locations[2].location.modified',
#  'doctor_locations[3].location.modified',
#  'doctor_locations[4].location.modified',
#  'doctor_locations[5].location.modified',
#  'doctor_locations[6].location.modified',
#  'doctor_locations[7].location.modified',
#  'doctor_locations[8].location.modified',
#  'doctor_locations[9].location.modified',
#  'doctor_locations[10].location.modified',
#  'doctor_locations[11].location.modified',
#  'doctor_locations[12].location.modified',
#  'doctor_locations[13].location.modified',
#  'doctor_locations[14].location.modified',
#  'doctor_locations[15].location.modified',
#  'doctor_locations[16].location.modified',
#  'doctor_locations[17].location.modified',
#  'doctor_locations[18].location.modified',
#  'doctor_locations[19].location.modified',
#  'doctor_locations[20].location.modified',
#  'doctor_locations[21].location.modified',
#  'doctor_locations[0].location.longitude',
#  'doctor_locations[1].location.longitude',
#  'doctor_locations[2].location.longitude',
#  'doctor_locations[3].location.longitude',
#  'doctor_locations[4].location.longitude',
#  'doctor_locations[5].location.longitude',
#  'doctor_locations[6].location.longitude',
#  'doctor_locations[7].location.longitude',
#  'doctor_locations[8].location.longitude',
#  'doctor_locations[9].location.longitude',
#  'doctor_locations[10].location.longitude',
#  'doctor_locations[11].location.longitude',
#  'doctor_locations[12].location.longitude',
#  'doctor_locations[13].location.longitude',
#  'doctor_locations[14].location.longitude',
#  'doctor_locations[15].location.longitude',
#  'doctor_locations[16].location.longitude',
#  'doctor_locations[17].location.longitude',
#  'doctor_locations[18].location.longitude',
#  'doctor_locations[19].location.longitude',
#  'doctor_locations[20].location.longitude',
#  'doctor_locations[21].location.longitude',
#  'doctor_locations[0].location.latitude',
#  'doctor_locations[1].location.latitude',
#  'doctor_locations[2].location.latitude',
#  'doctor_locations[3].location.latitude',
#  'doctor_locations[4].location.latitude',
#  'doctor_locations[5].location.latitude',
#  'doctor_locations[6].location.latitude',
#  'doctor_locations[7].location.latitude',
#  'doctor_locations[8].location.latitude',
#  'doctor_locations[9].location.latitude',
#  'doctor_locations[10].location.latitude',
#  'doctor_locations[11].location.latitude',
#  'doctor_locations[12].location.latitude',
#  'doctor_locations[13].location.latitude',
#  'doctor_locations[14].location.latitude',
#  'doctor_locations[15].location.latitude',
#  'doctor_locations[16].location.latitude',
#  'doctor_locations[17].location.latitude',
#  'doctor_locations[18].location.latitude',
#  'doctor_locations[19].location.latitude',
#  'doctor_locations[20].location.latitude',
#  'doctor_locations[21].location.latitude',
#  'doctor_locations[0].location.slug',
#  'doctor_locations[1].location.slug',
#  'doctor_locations[2].location.slug',
#  'doctor_locations[3].location.slug',
#  'doctor_locations[4].location.slug',
#  'doctor_locations[5].location.slug',
#  'doctor_locations[6].location.slug',
#  'doctor_locations[7].location.slug',
#  'doctor_locations[8].location.slug',
#  'doctor_locations[9].location.slug',
#  'doctor_locations[10].location.slug',
#  'doctor_locations[11].location.slug',
#  'doctor_locations[12].location.slug',
#  'doctor_locations[13].location.slug',
#  'doctor_locations[14].location.slug',
#  'doctor_locations[15].location.slug',
#  'doctor_locations[16].location.slug',
#  'doctor_locations[17].location.slug',
#  'doctor_locations[18].location.slug',
#  'doctor_locations[19].location.slug',
#  'doctor_locations[20].location.slug',
#  'doctor_locations[21].location.slug',
#  'doctor_locations[0].location.city.id',
#  'doctor_locations[1].location.city.id',
#  'doctor_locations[2].location.city.id',
#  'doctor_locations[3].location.city.id',
#  'doctor_locations[4].location.city.id',
#  'doctor_locations[5].location.city.id',
#  'doctor_locations[6].location.city.id',
#  'doctor_locations[7].location.city.id',
#  'doctor_locations[8].location.city.id',
#  'doctor_locations[9].location.city.id',
#  'doctor_locations[10].location.city.id',
#  'doctor_locations[11].location.city.id',
#  'doctor_locations[12].location.city.id',
#  'doctor_locations[13].location.city.id',
#  'doctor_locations[14].location.city.id',
#  'doctor_locations[15].location.city.id',
#  'doctor_locations[16].location.city.id',
#  'doctor_locations[17].location.city.id',
#  'doctor_locations[18].location.city.id',
#  'doctor_locations[19].location.city.id',
#  'doctor_locations[20].location.city.id',
#  'doctor_locations[21].location.city.id',
#  'doctor_locations[0].location.city.province_name',
#  'doctor_locations[1].location.city.province_name',
#  'doctor_locations[2].location.city.province_name',
#  'doctor_locations[3].location.city.province_name',
#  'doctor_locations[4].location.city.province_name',
#  'doctor_locations[5].location.city.province_name',
#  'doctor_locations[6].location.city.province_name',
#  'doctor_locations[7].location.city.province_name',
#  'doctor_locations[8].location.city.province_name',
#  'doctor_locations[9].location.city.province_name',
#  'doctor_locations[10].location.city.province_name',
#  'doctor_locations[11].location.city.province_name',
#  'doctor_locations[12].location.city.province_name',
#  'doctor_locations[13].location.city.province_name',
#  'doctor_locations[14].location.city.province_name',
#  'doctor_locations[15].location.city.province_name',
#  'doctor_locations[16].location.city.province_name',
#  'doctor_locations[17].location.city.province_name',
#  'doctor_locations[18].location.city.province_name',
#  'doctor_locations[19].location.city.province_name',
#  'doctor_locations[20].location.city.province_name',
#  'doctor_locations[21].location.city.province_name',
#  'doctor_locations[0].location.city.province_slug',
#  'doctor_locations[1].location.city.province_slug',
#  'doctor_locations[2].location.city.province_slug',
#  'doctor_locations[3].location.city.province_slug',
#  'doctor_locations[4].location.city.province_slug',
#  'doctor_locations[5].location.city.province_slug',
#  'doctor_locations[6].location.city.province_slug',
#  'doctor_locations[7].location.city.province_slug',
#  'doctor_locations[8].location.city.province_slug',
#  'doctor_locations[9].location.city.province_slug',
#  'doctor_locations[10].location.city.province_slug',
#  'doctor_locations[11].location.city.province_slug',
#  'doctor_locations[12].location.city.province_slug',
#  'doctor_locations[13].location.city.province_slug',
#  'doctor_locations[14].location.city.province_slug',
#  'doctor_locations[15].location.city.province_slug',
#  'doctor_locations[16].location.city.province_slug',
#  'doctor_locations[17].location.city.province_slug',
#  'doctor_locations[18].location.city.province_slug',
#  'doctor_locations[19].location.city.province_slug',
#  'doctor_locations[20].location.city.province_slug',
#  'doctor_locations[21].location.city.province_slug',
#  'doctor_locations[0].location.city.country_name',
#  'doctor_locations[1].location.city.country_name',
#  'doctor_locations[2].location.city.country_name',
#  'doctor_locations[3].location.city.country_name',
#  'doctor_locations[4].location.city.country_name',
#  'doctor_locations[5].location.city.country_name',
#  'doctor_locations[6].location.city.country_name',
#  'doctor_locations[7].location.city.country_name',
#  'doctor_locations[8].location.city.country_name',
#  'doctor_locations[9].location.city.country_name',
#  'doctor_locations[10].location.city.country_name',
#  'doctor_locations[11].location.city.country_name',
#  'doctor_locations[12].location.city.country_name',
#  'doctor_locations[13].location.city.country_name',
#  'doctor_locations[14].location.city.country_name',
#  'doctor_locations[15].location.city.country_name',
#  'doctor_locations[16].location.city.country_name',
#  'doctor_locations[17].location.city.country_name',
#  'doctor_locations[18].location.city.country_name',
#  'doctor_locations[19].location.city.country_name',
#  'doctor_locations[20].location.city.country_name',
#  'doctor_locations[21].location.city.country_name',
#  'doctor_locations[0].location.city.country_slug',
#  'doctor_locations[1].location.city.country_slug',
#  'doctor_locations[2].location.city.country_slug',
#  'doctor_locations[3].location.city.country_slug',
#  'doctor_locations[4].location.city.country_slug',
#  'doctor_locations[5].location.city.country_slug',
#  'doctor_locations[6].location.city.country_slug',
#  'doctor_locations[7].location.city.country_slug',
#  'doctor_locations[8].location.city.country_slug',
#  'doctor_locations[9].location.city.country_slug',
#  'doctor_locations[10].location.city.country_slug',
#  'doctor_locations[11].location.city.country_slug',
#  'doctor_locations[12].location.city.country_slug',
#  'doctor_locations[13].location.city.country_slug',
#  'doctor_locations[14].location.city.country_slug',
#  'doctor_locations[15].location.city.country_slug',
#  'doctor_locations[16].location.city.country_slug',
#  'doctor_locations[17].location.city.country_slug',
#  'doctor_locations[18].location.city.country_slug',
#  'doctor_locations[19].location.city.country_slug',
#  'doctor_locations[20].location.city.country_slug',
#  'doctor_locations[21].location.city.country_slug',
#  'doctor_locations[0].location.city.cover_images.253x83',
#  'doctor_locations[1].location.city.cover_images.253x83',
#  'doctor_locations[2].location.city.cover_images.253x83',
#  'doctor_locations[3].location.city.cover_images.253x83',
#  'doctor_locations[4].location.city.cover_images.253x83',
#  'doctor_locations[5].location.city.cover_images.253x83',
#  'doctor_locations[6].location.city.cover_images.253x83',
#  'doctor_locations[7].location.city.cover_images.253x83',
#  'doctor_locations[8].location.city.cover_images.253x83',
#  'doctor_locations[9].location.city.cover_images.253x83',
#  'doctor_locations[10].location.city.cover_images.253x83',
#  'doctor_locations[11].location.city.cover_images.253x83',
#  'doctor_locations[12].location.city.cover_images.253x83',
#  'doctor_locations[13].location.city.cover_images.253x83',
#  'doctor_locations[14].location.city.cover_images.253x83',
#  'doctor_locations[15].location.city.cover_images.253x83',
#  'doctor_locations[16].location.city.cover_images.253x83',
#  'doctor_locations[17].location.city.cover_images.253x83',
#  'doctor_locations[18].location.city.cover_images.253x83',
#  'doctor_locations[19].location.city.cover_images.253x83',
#  'doctor_locations[20].location.city.cover_images.253x83',
#  'doctor_locations[21].location.city.cover_images.253x83',
#  'doctor_locations[0].location.city.cover_images.autoxauto',
#  'doctor_locations[1].location.city.cover_images.autoxauto',
#  'doctor_locations[2].location.city.cover_images.autoxauto',
#  'doctor_locations[3].location.city.cover_images.autoxauto',
#  'doctor_locations[4].location.city.cover_images.autoxauto',
#  'doctor_locations[5].location.city.cover_images.autoxauto',
#  'doctor_locations[6].location.city.cover_images.autoxauto',
#  'doctor_locations[7].location.city.cover_images.autoxauto',
#  'doctor_locations[8].location.city.cover_images.autoxauto',
#  'doctor_locations[9].location.city.cover_images.autoxauto',
#  'doctor_locations[10].location.city.cover_images.autoxauto',
#  'doctor_locations[11].location.city.cover_images.autoxauto',
#  'doctor_locations[12].location.city.cover_images.autoxauto',
#  'doctor_locations[13].location.city.cover_images.autoxauto',
#  'doctor_locations[14].location.city.cover_images.autoxauto',
#  'doctor_locations[15].location.city.cover_images.autoxauto',
#  'doctor_locations[16].location.city.cover_images.autoxauto',
#  'doctor_locations[17].location.city.cover_images.autoxauto',
#  'doctor_locations[18].location.city.cover_images.autoxauto',
#  'doctor_locations[19].location.city.cover_images.autoxauto',
#  'doctor_locations[20].location.city.cover_images.autoxauto',
#  'doctor_locations[21].location.city.cover_images.autoxauto',
#  'doctor_locations[0].location.city.modified',
#  'doctor_locations[1].location.city.modified',
#  'doctor_locations[2].location.city.modified',
#  'doctor_locations[3].location.city.modified',
#  'doctor_locations[4].location.city.modified',
#  'doctor_locations[5].location.city.modified',
#  'doctor_locations[6].location.city.modified',
#  'doctor_locations[7].location.city.modified',
#  'doctor_locations[8].location.city.modified',
#  'doctor_locations[9].location.city.modified',
#  'doctor_locations[10].location.city.modified',
#  'doctor_locations[11].location.city.modified',
#  'doctor_locations[12].location.city.modified',
#  'doctor_locations[13].location.city.modified',
#  'doctor_locations[14].location.city.modified',
#  'doctor_locations[15].location.city.modified',
#  'doctor_locations[16].location.city.modified',
#  'doctor_locations[17].location.city.modified',
#  'doctor_locations[18].location.city.modified',
#  'doctor_locations[19].location.city.modified',
#  'doctor_locations[20].location.city.modified',
#  'doctor_locations[21].location.city.modified',
#  'doctor_locations[0].location.city.created',
#  'doctor_locations[1].location.city.created',
#  'doctor_locations[2].location.city.created',
#  'doctor_locations[3].location.city.created',
#  'doctor_locations[4].location.city.created',
#  'doctor_locations[5].location.city.created',
#  'doctor_locations[6].location.city.created',
#  'doctor_locations[7].location.city.created',
#  'doctor_locations[8].location.city.created',
#  'doctor_locations[9].location.city.created',
#  'doctor_locations[10].location.city.created',
#  'doctor_locations[11].location.city.created',
#  'doctor_locations[12].location.city.created',
#  'doctor_locations[13].location.city.created',
#  'doctor_locations[14].location.city.created',
#  'doctor_locations[15].location.city.created',
#  'doctor_locations[16].location.city.created',
#  'doctor_locations[17].location.city.created',
#  'doctor_locations[18].location.city.created',
#  'doctor_locations[19].location.city.created',
#  'doctor_locations[20].location.city.created',
#  'doctor_locations[21].location.city.created',
#  'doctor_locations[0].location.city.deleted',
#  'doctor_locations[1].location.city.deleted',
#  'doctor_locations[2].location.city.deleted',
#  'doctor_locations[3].location.city.deleted',
#  'doctor_locations[4].location.city.deleted',
#  'doctor_locations[5].location.city.deleted',
#  'doctor_locations[6].location.city.deleted',
#  'doctor_locations[7].location.city.deleted',
#  'doctor_locations[8].location.city.deleted',
#  'doctor_locations[9].location.city.deleted',
#  'doctor_locations[10].location.city.deleted',
#  'doctor_locations[11].location.city.deleted',
#  'doctor_locations[12].location.city.deleted',
#  'doctor_locations[13].location.city.deleted',
#  'doctor_locations[14].location.city.deleted',
#  'doctor_locations[15].location.city.deleted',
#  'doctor_locations[16].location.city.deleted',
#  'doctor_locations[17].location.city.deleted',
#  'doctor_locations[18].location.city.deleted',
#  'doctor_locations[19].location.city.deleted',
#  'doctor_locations[20].location.city.deleted',
#  'doctor_locations[21].location.city.deleted',
#  'doctor_locations[0].location.city.slug',
#  'doctor_locations[1].location.city.slug',
#  'doctor_locations[2].location.city.slug',
#  'doctor_locations[3].location.city.slug',
#  'doctor_locations[4].location.city.slug',
#  'doctor_locations[5].location.city.slug',
#  'doctor_locations[6].location.city.slug',
#  'doctor_locations[7].location.city.slug',
#  'doctor_locations[8].location.city.slug',
#  'doctor_locations[9].location.city.slug',
#  'doctor_locations[10].location.city.slug',
#  'doctor_locations[11].location.city.slug',
#  'doctor_locations[12].location.city.slug',
#  'doctor_locations[13].location.city.slug',
#  'doctor_locations[14].location.city.slug',
#  'doctor_locations[15].location.city.slug',
#  'doctor_locations[16].location.city.slug',
#  'doctor_locations[17].location.city.slug',
#  'doctor_locations[18].location.city.slug',
#  'doctor_locations[19].location.city.slug',
#  'doctor_locations[20].location.city.slug',
#  'doctor_locations[21].location.city.slug',
#  'doctor_locations[0].location.city.name',
#  'doctor_locations[1].location.city.name',
#  'doctor_locations[2].location.city.name',
#  'doctor_locations[3].location.city.name',
#  'doctor_locations[4].location.city.name',
#  'doctor_locations[5].location.city.name',
#  'doctor_locations[6].location.city.name',
#  'doctor_locations[7].location.city.name',
#  'doctor_locations[8].location.city.name',
#  'doctor_locations[9].location.city.name',
#  'doctor_locations[10].location.city.name',
#  'doctor_locations[11].location.city.name',
#  'doctor_locations[12].location.city.name',
#  'doctor_locations[13].location.city.name',
#  'doctor_locations[14].location.city.name',
#  'doctor_locations[15].location.city.name',
#  'doctor_locations[16].location.city.name',
#  'doctor_locations[17].location.city.name',
#  'doctor_locations[18].location.city.name',
#  'doctor_locations[19].location.city.name',
#  'doctor_locations[20].location.city.name',
#  'doctor_locations[21].location.city.name',
#  'doctor_locations[0].location.city.cover_image',
#  'doctor_locations[1].location.city.cover_image',
#  'doctor_locations[2].location.city.cover_image',
#  'doctor_locations[3].location.city.cover_image',
#  'doctor_locations[4].location.city.cover_image',
#  'doctor_locations[5].location.city.cover_image',
#  'doctor_locations[6].location.city.cover_image',
#  'doctor_locations[7].location.city.cover_image',
#  'doctor_locations[8].location.city.cover_image',
#  'doctor_locations[9].location.city.cover_image',
#  'doctor_locations[10].location.city.cover_image',
#  'doctor_locations[11].location.city.cover_image',
#  'doctor_locations[12].location.city.cover_image',
#  'doctor_locations[13].location.city.cover_image',
#  'doctor_locations[14].location.city.cover_image',
#  'doctor_locations[15].location.city.cover_image',
#  'doctor_locations[16].location.city.cover_image',
#  'doctor_locations[17].location.city.cover_image',
#  'doctor_locations[18].location.city.cover_image',
#  'doctor_locations[19].location.city.cover_image',
#  'doctor_locations[20].location.city.cover_image',
#  'doctor_locations[21].location.city.cover_image',
#  'doctor_locations[0].location.city.province',
#  'doctor_locations[1].location.city.province',
#  'doctor_locations[2].location.city.province',
#  'doctor_locations[3].location.city.province',
#  'doctor_locations[4].location.city.province',
#  'doctor_locations[5].location.city.province',
#  'doctor_locations[6].location.city.province',
#  'doctor_locations[7].location.city.province',
#  'doctor_locations[8].location.city.province',
#  'doctor_locations[9].location.city.province',
#  'doctor_locations[10].location.city.province',
#  'doctor_locations[11].location.city.province',
#  'doctor_locations[12].location.city.province',
#  'doctor_locations[13].location.city.province',
#  'doctor_locations[14].location.city.province',
#  'doctor_locations[15].location.city.province',
#  'doctor_locations[16].location.city.province',
#  'doctor_locations[17].location.city.province',
#  'doctor_locations[18].location.city.province',
#  'doctor_locations[19].location.city.province',
#  'doctor_locations[20].location.city.province',
#  'doctor_locations[21].location.city.province',
#  'doctor_locations[0].location.name',
#  'doctor_locations[1].location.name',
#  'doctor_locations[2].location.name',
#  'doctor_locations[3].location.name',
#  'doctor_locations[4].location.name',
#  'doctor_locations[5].location.name',
#  'doctor_locations[6].location.name',
#  'doctor_locations[7].location.name',
#  'doctor_locations[8].location.name',
#  'doctor_locations[9].location.name',
#  'doctor_locations[10].location.name',
#  'doctor_locations[11].location.name',
#  'doctor_locations[12].location.name',
#  'doctor_locations[13].location.name',
#  'doctor_locations[14].location.name',
#  'doctor_locations[15].location.name',
#  'doctor_locations[16].location.name',
#  'doctor_locations[17].location.name',
#  'doctor_locations[18].location.name',
#  'doctor_locations[19].location.name',
#  'doctor_locations[20].location.name',
#  'doctor_locations[21].location.name',
#  'doctor_locations[0].location.address',
#  'doctor_locations[1].location.address',
#  'doctor_locations[2].location.address',
#  'doctor_locations[3].location.address',
#  'doctor_locations[4].location.address',
#  'doctor_locations[5].location.address',
#  'doctor_locations[6].location.address',
#  'doctor_locations[7].location.address',
#  'doctor_locations[8].location.address',
#  'doctor_locations[9].location.address',
#  'doctor_locations[10].location.address',
#  'doctor_locations[11].location.address',
#  'doctor_locations[12].location.address',
#  'doctor_locations[13].location.address',
#  'doctor_locations[14].location.address',
#  'doctor_locations[15].location.address',
#  'doctor_locations[16].location.address',
#  'doctor_locations[17].location.address',
#  'doctor_locations[18].location.address',
#  'doctor_locations[19].location.address',
#  'doctor_locations[20].location.address',
#  'doctor_locations[21].location.address',
#  'doctor_locations[0].location.suite',
#  'doctor_locations[1].location.suite',
#  'doctor_locations[2].location.suite',
#  'doctor_locations[3].location.suite',
#  'doctor_locations[4].location.suite',
#  'doctor_locations[5].location.suite',
#  'doctor_locations[6].location.suite',
#  'doctor_locations[7].location.suite',
#  'doctor_locations[8].location.suite',
#  'doctor_locations[9].location.suite',
#  'doctor_locations[10].location.suite',
#  'doctor_locations[11].location.suite',
#  'doctor_locations[12].location.suite',
#  'doctor_locations[13].location.suite',
#  'doctor_locations[14].location.suite',
#  'doctor_locations[15].location.suite',
#  'doctor_locations[16].location.suite',
#  'doctor_locations[17].location.suite',
#  'doctor_locations[18].location.suite',
#  'doctor_locations[19].location.suite',
#  'doctor_locations[20].location.suite',
#  'doctor_locations[21].location.suite',
#  'doctor_locations[0].location.postal_code',
#  'doctor_locations[1].location.postal_code',
#  'doctor_locations[2].location.postal_code',
#  'doctor_locations[3].location.postal_code',
#  'doctor_locations[4].location.postal_code',
#  'doctor_locations[5].location.postal_code',
#  'doctor_locations[6].location.postal_code',
#  'doctor_locations[7].location.postal_code',
#  'doctor_locations[8].location.postal_code',
#  'doctor_locations[9].location.postal_code',
#  'doctor_locations[10].location.postal_code',
#  'doctor_locations[11].location.postal_code',
#  'doctor_locations[12].location.postal_code',
#  'doctor_locations[13].location.postal_code',
#  'doctor_locations[14].location.postal_code',
#  'doctor_locations[15].location.postal_code',
#  'doctor_locations[16].location.postal_code',
#  'doctor_locations[17].location.postal_code',
#  'doctor_locations[18].location.postal_code',
#  'doctor_locations[19].location.postal_code',
#  'doctor_locations[20].location.postal_code',
#  'doctor_locations[21].location.postal_code',
#  'doctor_locations[0].location.city_id',
#  'doctor_locations[1].location.city_id',
#  'doctor_locations[2].location.city_id',
#  'doctor_locations[3].location.city_id',
#  'doctor_locations[4].location.city_id',
#  'doctor_locations[5].location.city_id',
#  'doctor_locations[6].location.city_id',
#  'doctor_locations[7].location.city_id',
#  'doctor_locations[8].location.city_id',
#  'doctor_locations[9].location.city_id',
#  'doctor_locations[10].location.city_id',
#  'doctor_locations[11].location.city_id',
#  'doctor_locations[12].location.city_id',
#  'doctor_locations[13].location.city_id',
#  'doctor_locations[14].location.city_id',
#  'doctor_locations[15].location.city_id',
#  'doctor_locations[16].location.city_id',
#  'doctor_locations[17].location.city_id',
#  'doctor_locations[18].location.city_id',
#  'doctor_locations[19].location.city_id',
#  'doctor_locations[20].location.city_id',
#  'doctor_locations[21].location.city_id',
#  'doctor_locations[0].location.phone_number',
#  'doctor_locations[1].location.phone_number',
#  'doctor_locations[2].location.phone_number',
#  'doctor_locations[3].location.phone_number',
#  'doctor_locations[4].location.phone_number',
#  'doctor_locations[5].location.phone_number',
#  'doctor_locations[6].location.phone_number',
#  'doctor_locations[7].location.phone_number',
#  'doctor_locations[8].location.phone_number',
#  'doctor_locations[9].location.phone_number',
#  'doctor_locations[10].location.phone_number',
#  'doctor_locations[11].location.phone_number',
#  'doctor_locations[12].location.phone_number',
#  'doctor_locations[13].location.phone_number',
#  'doctor_locations[14].location.phone_number',
#  'doctor_locations[15].location.phone_number',
#  'doctor_locations[16].location.phone_number',
#  'doctor_locations[17].location.phone_number',
#  'doctor_locations[18].location.phone_number',
#  'doctor_locations[19].location.phone_number',
#  'doctor_locations[20].location.phone_number',
#  'doctor_locations[21].location.phone_number',
#  'doctor_locations[0].location.website',
#  'doctor_locations[1].location.website',
#  'doctor_locations[2].location.website',
#  'doctor_locations[3].location.website',
#  'doctor_locations[4].location.website',
#  'doctor_locations[5].location.website',
#  'doctor_locations[6].location.website',
#  'doctor_locations[7].location.website',
#  'doctor_locations[8].location.website',
#  'doctor_locations[9].location.website',
#  'doctor_locations[10].location.website',
#  'doctor_locations[11].location.website',
#  'doctor_locations[12].location.website',
#  'doctor_locations[13].location.website',
#  'doctor_locations[14].location.website',
#  'doctor_locations[15].location.website',
#  'doctor_locations[16].location.website',
#  'doctor_locations[17].location.website',
#  'doctor_locations[18].location.website',
#  'doctor_locations[19].location.website',
#  'doctor_locations[20].location.website',
#  'doctor_locations[21].location.website',
#  'doctor_locations[0].location.image',
#  'doctor_locations[1].location.image',
#  'doctor_locations[2].location.image',
#  'doctor_locations[3].location.image',
#  'doctor_locations[4].location.image',
#  'doctor_locations[5].location.image',
#  'doctor_locations[6].location.image',
#  'doctor_locations[7].location.image',
#  'doctor_locations[8].location.image',
#  'doctor_locations[9].location.image',
#  'doctor_locations[10].location.image',
#  'doctor_locations[11].location.image',
#  'doctor_locations[12].location.image',
#  'doctor_locations[13].location.image',
#  'doctor_locations[14].location.image',
#  'doctor_locations[15].location.image',
#  'doctor_locations[16].location.image',
#  'doctor_locations[17].location.image',
#  'doctor_locations[18].location.image',
#  'doctor_locations[19].location.image',
#  'doctor_locations[20].location.image',
#  'doctor_locations[21].location.image',
#  'doctor_locations[0].location.images.autoxauto',
#  'doctor_locations[1].location.images.autoxauto',
#  'doctor_locations[2].location.images.autoxauto',
#  'doctor_locations[3].location.images.autoxauto',
#  'doctor_locations[4].location.images.autoxauto',
#  'doctor_locations[5].location.images.autoxauto',
#  'doctor_locations[6].location.images.autoxauto',
#  'doctor_locations[7].location.images.autoxauto',
#  'doctor_locations[8].location.images.autoxauto',
#  'doctor_locations[9].location.images.autoxauto',
#  'doctor_locations[10].location.images.autoxauto',
#  'doctor_locations[11].location.images.autoxauto',
#  'doctor_locations[12].location.images.autoxauto',
#  'doctor_locations[13].location.images.autoxauto',
#  'doctor_locations[14].location.images.autoxauto',
#  'doctor_locations[15].location.images.autoxauto',
#  'doctor_locations[16].location.images.autoxauto',
#  'doctor_locations[17].location.images.autoxauto',
#  'doctor_locations[18].location.images.autoxauto',
#  'doctor_locations[19].location.images.autoxauto',
#  'doctor_locations[20].location.images.autoxauto',
#  'doctor_locations[21].location.images.autoxauto',
#  'doctor_locations[0].location.images.77x77',
#  'doctor_locations[1].location.images.77x77',
#  'doctor_locations[2].location.images.77x77',
#  'doctor_locations[3].location.images.77x77',
#  'doctor_locations[4].location.images.77x77',
#  'doctor_locations[5].location.images.77x77',
#  'doctor_locations[6].location.images.77x77',
#  'doctor_locations[7].location.images.77x77',
#  'doctor_locations[8].location.images.77x77',
#  'doctor_locations[9].location.images.77x77',
#  'doctor_locations[10].location.images.77x77',
#  'doctor_locations[11].location.images.77x77',
#  'doctor_locations[12].location.images.77x77',
#  'doctor_locations[13].location.images.77x77',
#  'doctor_locations[14].location.images.77x77',
#  'doctor_locations[15].location.images.77x77',
#  'doctor_locations[16].location.images.77x77',
#  'doctor_locations[17].location.images.77x77',
#  'doctor_locations[18].location.images.77x77',
#  'doctor_locations[19].location.images.77x77',
#  'doctor_locations[20].location.images.77x77',
#  'doctor_locations[21].location.images.77x77',
#  'doctor_locations[0].location.images.100x100',
#  'doctor_locations[1].location.images.100x100',
#  'doctor_locations[2].location.images.100x100',
#  'doctor_locations[3].location.images.100x100',
#  'doctor_locations[4].location.images.100x100',
#  'doctor_locations[5].location.images.100x100',
#  'doctor_locations[6].location.images.100x100',
#  'doctor_locations[7].location.images.100x100',
#  'doctor_locations[8].location.images.100x100',
#  'doctor_locations[9].location.images.100x100',
#  'doctor_locations[10].location.images.100x100',
#  'doctor_locations[11].location.images.100x100',
#  'doctor_locations[12].location.images.100x100',
#  'doctor_locations[13].location.images.100x100',
#  'doctor_locations[14].location.images.100x100',
#  'doctor_locations[15].location.images.100x100',
#  'doctor_locations[16].location.images.100x100',
#  'doctor_locations[17].location.images.100x100',
#  'doctor_locations[18].location.images.100x100',
#  'doctor_locations[19].location.images.100x100',
#  'doctor_locations[20].location.images.100x100',
#  'doctor_locations[21].location.images.100x100',
#  'doctor_locations[0].location.images.165x165',
#  'doctor_locations[1].location.images.165x165',
#  'doctor_locations[2].location.images.165x165',
#  'doctor_locations[3].location.images.165x165',
#  'doctor_locations[4].location.images.165x165',
#  'doctor_locations[5].location.images.165x165',
#  'doctor_locations[6].location.images.165x165',
#  'doctor_locations[7].location.images.165x165',
#  'doctor_locations[8].location.images.165x165',
#  'doctor_locations[9].location.images.165x165',
#  'doctor_locations[10].location.images.165x165',
#  'doctor_locations[11].location.images.165x165',
#  'doctor_locations[12].location.images.165x165',
#  'doctor_locations[13].location.images.165x165',
#  'doctor_locations[14].location.images.165x165',
#  'doctor_locations[15].location.images.165x165',
#  'doctor_locations[16].location.images.165x165',
#  'doctor_locations[17].location.images.165x165',
#  'doctor_locations[18].location.images.165x165',
#  'doctor_locations[19].location.images.165x165',
#  'doctor_locations[20].location.images.165x165',
#  'doctor_locations[21].location.images.165x165',
#  'doctor_locations[0].location.images.70x70',
#  'doctor_locations[1].location.images.70x70',
#  'doctor_locations[2].location.images.70x70',
#  'doctor_locations[3].location.images.70x70',
#  'doctor_locations[4].location.images.70x70',
#  'doctor_locations[6].location.images.70x70',
#  'doctor_locations[5].location.images.70x70',
#  'doctor_locations[7].location.images.70x70',
#  'doctor_locations[8].location.images.70x70',
#  'doctor_locations[9].location.images.70x70',
#  'doctor_locations[10].location.images.70x70',
#  'doctor_locations[11].location.images.70x70',
#  'doctor_locations[12].location.images.70x70',
#  'doctor_locations[13].location.images.70x70',
#  'doctor_locations[14].location.images.70x70',
#  'doctor_locations[15].location.images.70x70',
#  'doctor_locations[16].location.images.70x70',
#  'doctor_locations[17].location.images.70x70',
#  'doctor_locations[18].location.images.70x70',
#  'doctor_locations[19].location.images.70x70',
#  'doctor_locations[20].location.images.70x70',
#  'doctor_locations[21].location.images.70x70',
#  'doctor_locations[0].location.rating.cleanliness',
#  'doctor_locations[1].location.rating.cleanliness',
#  'doctor_locations[2].location.rating.cleanliness',
#  'doctor_locations[3].location.rating.cleanliness',
#  'doctor_locations[4].location.rating.cleanliness',
#  'doctor_locations[5].location.rating.cleanliness',
#  'doctor_locations[6].location.rating.cleanliness',
#  'doctor_locations[7].location.rating.cleanliness',
#  'doctor_locations[8].location.rating.cleanliness',
#  'doctor_locations[9].location.rating.cleanliness',
#  'doctor_locations[10].location.rating.cleanliness',
#  'doctor_locations[11].location.rating.cleanliness',
#  'doctor_locations[12].location.rating.cleanliness',
#  'doctor_locations[13].location.rating.cleanliness',
#  'doctor_locations[14].location.rating.cleanliness',
#  'doctor_locations[15].location.rating.cleanliness',
#  'doctor_locations[16].location.rating.cleanliness',
#  'doctor_locations[17].location.rating.cleanliness',
#  'doctor_locations[18].location.rating.cleanliness',
#  'doctor_locations[19].location.rating.cleanliness',
#  'doctor_locations[20].location.rating.cleanliness',
#  'doctor_locations[21].location.rating.cleanliness',
#  'doctor_locations[0].location.rating.facilities',
#  'doctor_locations[1].location.rating.facilities',
#  'doctor_locations[2].location.rating.facilities',
#  'doctor_locations[3].location.rating.facilities',
#  'doctor_locations[4].location.rating.facilities',
#  'doctor_locations[5].location.rating.facilities',
#  'doctor_locations[6].location.rating.facilities',
#  'doctor_locations[7].location.rating.facilities',
#  'doctor_locations[8].location.rating.facilities',
#  'doctor_locations[9].location.rating.facilities',
#  'doctor_locations[10].location.rating.facilities',
#  'doctor_locations[11].location.rating.facilities',
#  'doctor_locations[12].location.rating.facilities',
#  'doctor_locations[13].location.rating.facilities',
#  'doctor_locations[14].location.rating.facilities',
#  'doctor_locations[15].location.rating.facilities',
#  'doctor_locations[16].location.rating.facilities',
#  'doctor_locations[17].location.rating.facilities',
#  'doctor_locations[18].location.rating.facilities',
#  'doctor_locations[19].location.rating.facilities',
#  'doctor_locations[20].location.rating.facilities',
#  'doctor_locations[21].location.rating.facilities',
#  'doctor_locations[0].location.rating.services',
#  'doctor_locations[1].location.rating.services',
#  'doctor_locations[2].location.rating.services',
#  'doctor_locations[3].location.rating.services',
#  'doctor_locations[4].location.rating.services',
#  'doctor_locations[5].location.rating.services',
#  'doctor_locations[6].location.rating.services',
#  'doctor_locations[7].location.rating.services',
#  'doctor_locations[8].location.rating.services',
#  'doctor_locations[9].location.rating.services',
#  'doctor_locations[10].location.rating.services',
#  'doctor_locations[11].location.rating.services',
#  'doctor_locations[12].location.rating.services',
#  'doctor_locations[13].location.rating.services',
#  'doctor_locations[14].location.rating.services',
#  'doctor_locations[15].location.rating.services',
#  'doctor_locations[16].location.rating.services',
#  'doctor_locations[17].location.rating.services',
#  'doctor_locations[18].location.rating.services',
#  'doctor_locations[19].location.rating.services',
#  'doctor_locations[20].location.rating.services',
#  'doctor_locations[21].location.rating.services',
#  'doctor_locations[0].location.rating.bestRating',
#  'doctor_locations[1].location.rating.bestRating',
#  'doctor_locations[2].location.rating.bestRating',
#  'doctor_locations[3].location.rating.bestRating',
#  'doctor_locations[4].location.rating.bestRating',
#  'doctor_locations[5].location.rating.bestRating',
#  'doctor_locations[6].location.rating.bestRating',
#  'doctor_locations[7].location.rating.bestRating',
#  'doctor_locations[8].location.rating.bestRating',
#  'doctor_locations[9].location.rating.bestRating',
#  'doctor_locations[10].location.rating.bestRating',
#  'doctor_locations[11].location.rating.bestRating',
#  'doctor_locations[12].location.rating.bestRating',
#  'doctor_locations[13].location.rating.bestRating',
#  'doctor_locations[14].location.rating.bestRating',
#  'doctor_locations[15].location.rating.bestRating',
#  'doctor_locations[16].location.rating.bestRating',
#  'doctor_locations[17].location.rating.bestRating',
#  'doctor_locations[18].location.rating.bestRating',
#  'doctor_locations[19].location.rating.bestRating',
#  'doctor_locations[20].location.rating.bestRating',
#  'doctor_locations[21].location.rating.bestRating',
#  'doctor_locations[0].location.rating.average',
#  'doctor_locations[1].location.rating.average',
#  'doctor_locations[2].location.rating.average',
#  'doctor_locations[3].location.rating.average',
#  'doctor_locations[4].location.rating.average',
#  'doctor_locations[5].location.rating.average',
#  'doctor_locations[6].location.rating.average',
#  'doctor_locations[7].location.rating.average',
#  'doctor_locations[8].location.rating.average',
#  'doctor_locations[9].location.rating.average',
#  'doctor_locations[10].location.rating.average',
#  'doctor_locations[11].location.rating.average',
#  'doctor_locations[12].location.rating.average',
#  'doctor_locations[13].location.rating.average',
#  'doctor_locations[14].location.rating.average',
#  'doctor_locations[15].location.rating.average',
#  'doctor_locations[16].location.rating.average',
#  'doctor_locations[17].location.rating.average',
#  'doctor_locations[18].location.rating.average',
#  'doctor_locations[19].location.rating.average',
#  ...]

# %% [markdown]
# Data Preparation (Cleaning the Data)

# %% [markdown]
# The raw data set from the CSV file contained 1,611 columns and 143,791 rows. That in itself is too much to analyze, and also contained fields such as images, phone numbers, etc... Field that would be irrelivant to our analysis, and research question. So this calls for some data cleaning!
#
# * We selected a focused subset of 9 relevant variables that describe each doctor’s name, specialty, city, and core rating metrics.
#
# * We renamed the columns to simpler names. Column names were written such as "location.city.name", "rating.average" so we changed them to "city" and "rating_average"
#
# * Rating fields were stored as mixed text/numeric types so we converted the rating columns to numeric using pd.to_numeric(df_clean[col], errors="coerce")
#
# * We filtered out zero rating doctors to make sure we only analyze doctors who have actual patient reviews in order to produce valid insights
#
# * After filtering, we reset the index for smooth readability

# %%
# ---------- DATA CLEANING ----------
# Select usable columns
cols_to_keep = [
    "_id", "full_name", "specialty_name", "location.city.name",
    "rating.average", "rating.helpfulness", "rating.punctuality",
    "rating.staff", "rating.count"
]

df_clean = df[cols_to_keep].copy()

# Rename columns to simpler names
df_clean = df_clean.rename(columns={
    "location.city.name": "city",
    "rating.average": "rating_avg",
    "rating.helpfulness": "rating_help",
    "rating.punctuality": "rating_punctuality",
    "rating.staff": "rating_staff",
    "rating.count": "rating_count"
})

# Convert numeric columns to proper numeric types
numeric_cols = [
    "rating_avg", "rating_help", "rating_punctuality",
    "rating_staff", "rating_count"
]

for col in numeric_cols:
    df_clean[col] = pd.to_numeric(df_clean[col], errors="coerce")

# Drop rows with no rating information
df_clean = df_clean.dropna(subset=["rating_avg"])

# Before having this the rating avg and rating_help was 0's
df_clean = df_clean[df_clean["rating_count"] > 0]
df_clean = df_clean[df_clean["rating_avg"] > 0]

# Reset index
df_clean = df_clean.reset_index(drop=True)

df_clean.head() # this is to see the clean data
# Out:
#                         _id                full_name  \
# 0  647e89e399dca372f92a0d7c      Dr. Janan S. Sayyed
# 1  647e89e499dca372f92a0d91        Dr. Shirin Peters
# 2  647e89e499dca372f92a0e14        Dr. Lev L. Barats
# 3  647e89e499dca372f92a0ef0  Dr. Harold N. Bornstein
# 4  647e89e499dca372f92a0ef2   Dr. Romelle J. Maloney
#
#              specialty_name           city  rating_avg  rating_help  \
# 0              Chiropractor  New York City    4.989221     4.993367
# 1  Internist / Geriatrician  New York City    5.000000     5.000000
# 2  Internist / Geriatrician   Slingerlands    4.000000     3.800000
# 3  Internist / Geriatrician  New York City    4.000000     4.200000
# 4      Gynecologist (OBGYN)   New Rochelle    4.000000     3.900000
#
#    rating_punctuality  rating_staff  rating_count
# 0            4.985075       4.99005           603
# 1            5.000000       5.00000            48
# 2            4.100000       3.80000            10
# 3            3.800000       4.20000            10
# 4            4.100000       3.80000            10

# %%
df.head(50) # this is unclean data
# Out:
#                          _id  \
# 0   647e89e399dca372f92a0d7c
# 1   647e89e499dca372f92a0d91
# 2   647e89e499dca372f92a0db9
# 3   647e89e499dca372f92a0dba
# 4   647e89e499dca372f92a0dbd
# 5   647e89e499dca372f92a0dc3
# 6   647e89e499dca372f92a0de4
# 7   647e89e499dca372f92a0df1
# 38       Dr. Armando M. Aloran       Dr. Armando M. Aloran      1078582
# 39           Dr. Blair Kokotek           Dr. Blair Kokotek      1078638
# 40        Dr. Daniel J. Bisono        Dr. Daniel J. Bisono      1078645
# 41          Dr. Eman Al-Janabi          Dr. Eman Al-Janabi      1958203
# 42      Dr. Cynthia A. Treiber      Dr. Cynthia A. Treiber      1078775
# 43                Ann B. Green                Ann B. Green      1078845
# 44         Dr. Marco A. Oshiro         Dr. Marco A. Oshiro      1078865
# 45          Dr. Cindi L. Hartz          Dr. Cindi L. Hartz      1079142
# 46            Dr. Rose Mesidor            Dr. Rose Mesidor      1079145
# 47           Dr. Dennis S. Chi           Dr. Dennis S. Chi      1986940
# 48         Dr. Bertha D. Bravo         Dr. Bertha D. Bravo      2219581
# 49          Dr. Frank Peritore          Dr. Frank Peritore      1079318
#
#    location.category  ... doctor_location_hours[8].location.url  \
# 0             clinic  ...                                   NaN
# 1             clinic  ...                                   NaN
# 2             clinic  ...                                   NaN
# 3             clinic  ...                                   NaN
# 4             clinic  ...                                   NaN
# 5             clinic  ...                                   NaN
# 6             clinic  ...                                   NaN
# 7             clinic  ...                                   NaN
# 8             clinic  ...                                   NaN
# 9             clinic  ...                                   NaN
# 10            clinic  ...                                   NaN
# 11            clinic  ...                                   NaN
# 12            clinic  ...                                   NaN
# 13            clinic  ...                                   NaN
# 14            clinic  ...                                   NaN
# 15            clinic  ...                                   NaN
# 16            clinic  ...                                   NaN
# 17            clinic  ...                                   NaN
# 18            clinic  ...                                   NaN
# 19            clinic  ...                                   NaN
# 20            clinic  ...                                   NaN
# 21            clinic  ...                                   NaN
# 22            clinic  ...                                   NaN
# 23            clinic  ...                                   NaN
# 24            clinic  ...                                   NaN
# 25            clinic  ...                                   NaN
# 26            clinic  ...                                   NaN
# 27            clinic  ...                                   NaN
# 28            clinic  ...                                   NaN
# 29            clinic  ...                                   NaN
# 30            clinic  ...                                   NaN
# 31            clinic  ...                                   NaN
# 32            clinic  ...                                   NaN
# 33            clinic  ...                                   NaN
# 34            clinic  ...                                   NaN
# 35            clinic  ...                                   NaN
# 36            clinic  ...                                   NaN
# 37            clinic  ...                                   NaN
# 38            clinic  ...                                   NaN
# 39            clinic  ...                                   NaN
# 40            clinic  ...                                   NaN
# 41            clinic  ...                                   NaN
# 42            clinic  ...                                   NaN
# 43            clinic  ...                                   NaN
# 44            clinic  ...                                   NaN
# 45            clinic  ...                                   NaN
# 46            clinic  ...                                   NaN
# 47            clinic  ...                                   NaN
# 48            clinic  ...                                   NaN
# 49            clinic  ...                                   NaN
#
#    doctor_location_hours[0].location.geocode_address  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33                                               NaN
# 34                                               NaN
# 35                                               NaN
# 36                                               NaN
# 37                                               NaN
# 38                                               NaN
# 39                                               NaN
# 40                                               NaN
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
# 45                                               NaN
# 46                                               NaN
# 47                                               NaN
# 48                                               NaN
# 49                                               NaN
#
#     doctor_location_hours[1].location.geocode_address  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#     doctor_location_hours[2].location.geocode_address  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#    doctor_location_hours[3].location.geocode_address  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33                                               NaN
# 34                                               NaN
# 35                                               NaN
# 36                                               NaN
# 37                                               NaN
# 38                                               NaN
# 39                                               NaN
# 40                                               NaN
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
# 45                                               NaN
# 46                                               NaN
# 47                                               NaN
# 48                                               NaN
# 49                                               NaN
#
#     doctor_location_hours[4].location.geocode_address  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#    doctor_location_hours[5].location.geocode_address  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33                                               NaN
# 34                                               NaN
# 35                                               NaN
# 36                                               NaN
# 37                                               NaN
# 38                                               NaN
# 39                                               NaN
# 40                                               NaN
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
# 45                                               NaN
# 46                                               NaN
# 47                                               NaN
# 48                                               NaN
# 49                                               NaN
#
#    doctor_location_hours[6].location.geocode_address  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33                                               NaN
# 34                                               NaN
# 35                                               NaN
# 36                                               NaN
# 37                                               NaN
# 38                                               NaN
# 39                                               NaN
# 40                                               NaN
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
# 45                                               NaN
# 46                                               NaN
# 47                                               NaN
# 48                                               NaN
# 49                                               NaN
#
#    doctor_location_hours[7].location.geocode_address  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33                                               NaN
# 34                                               NaN
# 35                                               NaN
# 36                                               NaN
# 37                                               NaN
# 38                                               NaN
# 39                                               NaN
# 40                                               NaN
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
# 45                                               NaN
# 46                                               NaN
# 47                                               NaN
# 48                                               NaN
# 49                                               NaN
#
#    doctor_location_hours[8].location.geocode_address
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33                                               NaN
# 34                                               NaN
# 35                                               NaN
# 36                                               NaN
# 37                                               NaN
# 38                                               NaN
# 39                                               NaN
# 40                                               NaN
# 41                                               NaN
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
# 45                                               NaN
# 46                                               NaN
# 47                                               NaN
# 48                                               NaN
# 49                                               NaN
#
# [50 rows x 1611 columns]
